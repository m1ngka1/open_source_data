# %%
import akshare as ak

# %% [markdown]
# ### 总结
#
# 本质是爬虫工具，接口速度与稳定性均堪忧，任选股票历史数据与网页查询结果存在出入

# %% [markdown]
# ### 沪A股实盘

# %%
stock_sh_a_spot_em_df = ak.stock_sh_a_spot_em()
display(stock_sh_a_spot_em_df)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/miniconda3/envs/open_source_data/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/miniconda3/envs/open_source_data/lib/python3.13/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %% [markdown]
# ### 历史行情 - 东财
#
# 已知问题： 无法传入股票列表同时获得多个股票数据

# %%
stock_zh_a_hist_df = ak.stock_zh_a_hist(symbol="000001", period="daily", start_date="20170301", end_date='20240528', adjust="")
display(stock_zh_a_hist_df)
# Out:
#               日期    股票代码     开盘     收盘     最高     最低      成交量           成交额  \
# 0     2017-03-01  000001   9.49   9.49   9.55   9.47   346994  3.301580e+08
# 1     2017-03-02  000001   9.51   9.43   9.54   9.42   403629  3.823959e+08
# 2     2017-03-03  000001   9.41   9.40   9.43   9.36   342655  3.219525e+08
# 3     2017-03-06  000001   9.40   9.45   9.46   9.39   404511  3.812123e+08
# 4     2017-03-07  000001   9.44   9.45   9.46   9.40   294673  2.777474e+08
# ...          ...     ...    ...    ...    ...    ...      ...           ...
# 1755  2024-05-22  000001  11.56  11.56  11.74  11.46  2115531  2.458449e+09
# 1756  2024-05-23  000001  11.53  11.40  11.59  11.37  1841623  2.110799e+09
# 1757  2024-05-24  000001  11.37  11.31  11.49  11.30  1398276  1.593330e+09
# 1758  2024-05-27  000001  11.31  11.51  11.53  11.31  1454361  1.663272e+09
# 1759  2024-05-28  000001  11.50  11.40  11.58  11.36  1204323  1.377107e+09
#
#         振幅   涨跌幅   涨跌额   换手率
# ...

# %% [markdown]
# ### 任选一支股票，获取的数据与网页查询数据不一致
#
# 300031: 2024/5/28, 不复权，收盘24.22

# %%
ak.stock_zh_a_hist(symbol="300031", period="daily", start_date="20170301", end_date='20240528', adjust="")
# Out:
#               日期    股票代码     开盘     收盘     最高     最低     成交量          成交额  \
# 0     2017-03-01  300031  22.17  22.50  22.68  21.85   78975  177471469.0
# 1     2017-03-02  300031  22.57  22.47  22.80  22.36   36984   83236635.0
# 2     2017-03-03  300031  22.47  22.48  22.79  22.15   33445   74681994.0
# 3     2017-03-06  300031  22.36  23.16  23.34  22.36   59913  138615059.0
# 4     2017-03-07  300031  23.16  23.26  23.52  23.13   38902   90786081.0
# ...          ...     ...    ...    ...    ...    ...     ...          ...
# 1745  2024-05-22  300031  14.70  14.86  14.87  14.55  185953  274292602.0
# 1746  2024-05-23  300031  14.81  14.47  15.10  14.45  196910  289969252.0
# 1747  2024-05-24  300031  14.45  14.33  14.60  14.26  131858  189728874.0
# 1748  2024-05-27  300031  14.43  14.38  14.48  13.88  140699  198573322.0
# 1749  2024-05-28  300031  14.32  13.96  14.35  13.90  119584  167834972.0
#
#         振幅   涨跌幅   涨跌额   换手率
# 0     3.78  2.46  0.54  3.47
# ...

# %% [markdown]
#  # 股票信息
#  - "stock_info_sz_name_code"  # 深证证券交易所股票代码和简称
#  - "stock_info_sh_name_code"  # 上海证券交易所股票代码和简称
#  - "stock_info_bj_name_code"  # 北京证券交易所股票代码和简称
#  - "stock_info_sh_delist"  # 上海证券交易所暂停和终止上市
#  - "stock_info_sz_delist"  # 深证证券交易所暂停和终止上市
#  - "stock_info_sz_change_name"  # 深证证券交易所名称变更
#  - "stock_info_change_name"  # A 股股票曾用名列表
#  - "stock_info_a_code_name"  # A 股股票代码和简称

# %%
ak.stock_info_sz_name_code('A股列表')
# Out:
#        板块    A股代码   A股简称      A股上市日期           A股总股本          A股流通股本    所属行业
# 0      主板  000001   平安银行  1991-04-03  19,405,918,198  19,405,600,653   J 金融业
# 1      主板  000002  万  科Ａ  1991-01-29   9,724,196,533   9,716,812,790   K 房地产
# 2      主板  000004  *ST国华  1990-12-01     132,380,282     126,287,768  I 信息技术
# 3      主板  000006   深振业Ａ  1992-04-27   1,349,995,046   1,349,987,396   K 房地产
# 4      主板  000007    全新好  1992-04-13     346,448,044     346,448,044   K 房地产
# ...   ...     ...    ...         ...             ...             ...     ...
# 2863  创业板  301636   泽润新能  2025-05-16      63,867,823      15,141,113   C 制造业
# 2864  创业板  301658   首航新能  2025-04-02     412,371,135      38,728,009   C 制造业
# 2865  创业板  301662   宏工科技  2025-04-17      80,000,000      15,776,325   C 制造业
# 2866  创业板  301665   泰禾股份  2025-04-11     450,000,000      35,906,289   C 制造业
# 2867  创业板  302132   中航成飞  2010-08-27   2,676,782,376     590,719,499   C 制造业
#
# [2868 rows x 7 columns]

# %%
ak.stock_info_a_code_name()
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
#         code   name
# 0     000001   平安银行
# 1     000002  万  科Ａ
# 2     000004  *ST国华
# 3     000006   深振业Ａ
# 4     000007    全新好
# ...      ...    ...
# 5413  920445   龙竹科技
# 5414  920489   佳先股份
# 5415  920682   球冠电缆
# 5416  920799   艾融软件
# 5417  920819   颖泰生物
#
# [5418 rows x 2 columns]
